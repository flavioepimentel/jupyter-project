# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/countries.csv')

# %%
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
# Cheking the return
data.country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
# Getting only the true rows
br = data[data.country == 'Brazil']
br
# Out:
#     country  year  population
# 168  Brazil  1952    56602560
# 169  Brazil  1957    65551171
# 170  Brazil  1962    76039390
# 171  Brazil  1967    88049823
# 172  Brazil  1972   100840058
# 173  Brazil  1977   114313951
# 174  Brazil  1982   128962939
# 175  Brazil  1987   142938076
# 176  Brazil  1992   155975974
# 177  Brazil  1997   168546719
# 178  Brazil  2002   179914212
# 179  Brazil  2007   190010647

# %%
us = data[data.country == 'United States']
us
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
ch = data[data.country == "China"]
ch
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
# Comparing
plt.plot(br.year, us.population / 10 ** 6)
plt.plot(br.year, ch.population / 10 ** 6)
plt.plot(br.year, br.population / 10 ** 6)
plt.title('Population growth')
plt.xlabel('Years')
plt.ylabel('Population MM')
plt.legend(['United States', 'China', 'Brazil'])
plt.show()

# %%
# Comparing the percentual value
plt.plot(br.year, us.population / us.population.iloc[0] * 100)
plt.plot(br.year, ch.population / ch.population.iloc[0] * 100)
plt.plot(br.year, br.population / br.population.iloc[0] * 100)
plt.title('Percentual growth')
plt.xlabel('Years')
plt.ylabel('% Growth')
plt.legend(['United States', 'China', 'Brazil'])
plt.show()

# %%
# Check the percentual growth year by year
for n in br:
    plt.plot(br.year, br.population.iloc[n] / br.population.iloc[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-2d0ea8d7a94a> in <module>
#       1 # Check the percentual growth year by year
#       2 for n in br:
# ----> 3     plt.plot(br.year, br.population.iloc[n] / br.population.iloc[0])
#       4
#
# c:\users\flavi\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# c:\users\flavi\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1496             key = item_from_zerodim(key)
#    1497             if not is_integer(key):
# ...
